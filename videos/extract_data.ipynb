# %%
import csv
from collections import defaultdict

# %%
def read_csv_to_dict(file_path, names):
    """
    Reads a CSV file with columns: name, year, number
    and returns a dict of the form:
    {
        year1: {name1: number1, name2: number2, ...},
        year2: {...}
    }
    
    Only includes names in the given list.
    """
    data = defaultdict(dict)

    with open(file_path, newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)

        for row in reader:
            name = row["Entity"]
            year = int(row["Year"])
            number = int(row["Deaths in ongoing conflicts (best estimate) - Conflict type: all"])

            if name in names:
                data[year][name] = number

    return dict(data)

# %%
names = ['Ukraine', 'Democratic Republic of Congo', 'Russia', 'Palestine', 'Sudan', 'Syria', 'Burkina Faso', 'Mexico', 'Somalia', 'Pakistan']

# %%
read_csv_to_dict(file_path='deaths-in-armed-conflicts-by-region.csv', names=names)
# Out:
# {1989: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 28,
#   'Mexico': 2,
#   'Pakistan': 114,
#   'Palestine': 59,
#   'Russia': 0,
#   'Somalia': 1061,
#   'Sudan': 3609,
#   'Syria': 0,
#   'Ukraine': 0},
#  1990: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 147,
#   'Mexico': 0,
#   'Pakistan': 379,
#   'Palestine': 16,
#   'Russia': 0,
#   'Somalia': 2700,
#   'Sudan': 1063,
#   'Syria': 0,
#   'Ukraine': 0},
#  1991: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 32,
#   'Mexico': 0,
#   'Pakistan': 27,
#   'Palestine': 12,
#   'Russia': 0,
#   'Somalia': 8455,
#   'Sudan': 359,
#   'Syria': 0,
#   'Ukraine': 0},
#  1992: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 67,
#   'Mexico': 0,
#   'Pakistan': 50,
#   'Palestine': 29,
#   'Russia': 0,
#   'Somalia': 4729,
#   'Sudan': 968,
#   'Syria': 0,
#   'Ukraine': 0},
#  1993: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 3337,
#   'Mexico': 27,
#   'Pakistan': 33,
#   'Palestine': 31,
#   'Russia': 145,
#   'Somalia': 478,
#   'Sudan': 148,
#   'Syria': 0,
#   'Ukraine': 0},
#  1994: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 309,
#   'Mexico': 145,
#   'Pakistan': 161,
#   'Palestine': 48,
#   'Russia': 473,
#   'Somalia': 625,
#   'Sudan': 467,
#   'Syria': 0,
#   'Ukraine': 0},
#  1995: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 523,
#   'Mexico': 1,
#   'Pakistan': 111,
#   'Palestine': 9,
#   'Russia': 1891,
#   'Somalia': 443,
#   'Sudan': 332,
#   'Syria': 0,
#   'Ukraine': 0},
#  1996: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 34285,
#   'Mexico': 37,
#   'Pakistan': 47,
#   'Palestine': 64,
#   'Russia': 2763,
#   'Somalia': 939,
#   'Sudan': 340,
#   'Syria': 0,
#   'Ukraine': 0},
#  1997: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 13897,
#   'Mexico': 45,
#   'Pakistan': 120,
#   'Palestine': 0,
#   'Russia': 0,
#   'Somalia': 268,
#   'Sudan': 1230,
#   'Syria': 0,
#   'Ukraine': 0},
#  1998: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 7693,
#   'Mexico': 0,
#   'Pakistan': 130,
#   'Palestine': 0,
#   'Russia': 0,
#   'Somalia': 312,
#   'Sudan': 2053,
#   'Syria': 0,
#   'Ukraine': 0},
#  1999: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 7836,
#   'Mexico': 0,
#   'Pakistan': 66,
#   'Palestine': 0,
#   'Russia': 6197,
#   'Somalia': 522,
#   'Sudan': 1506,
#   'Syria': 0,
#   'Ukraine': 0},
#  2000: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 3045,
#   'Mexico': 0,
#   'Pakistan': 114,
#   'Palestine': 75,
#   'Russia': 4318,
#   'Somalia': 171,
#   'Sudan': 1573,
#   'Syria': 1,
#   'Ukraine': 0},
#  2001: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 1428,
#   'Mexico': 0,
#   'Pakistan': 36,
#   'Palestine': 224,
#   'Russia': 979,
#   'Somalia': 445,
#   'Sudan': 910,
#   'Syria': 0,
#   'Ukraine': 0},
#  2002: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 7877,
#   'Mexico': 26,
#   'Pakistan': 159,
#   'Palestine': 577,
#   'Russia': 1493,
#   'Somalia': 624,
#   'Sudan': 249,
#   'Syria': 0,
#   'Ukraine': 0},
#  2003: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 4310,
#   'Mexico': 0,
#   'Pakistan': 293,
#   'Palestine': 285,
#   'Russia': 548,
#   'Somalia': 395,
#   'Sudan': 4761,
#   'Syria': 0,
#   'Ukraine': 0},
#  2004: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 751,
#   'Mexico': 216,
#   'Pakistan': 437,
#   'Palestine': 396,
#   'Russia': 1300,
#   'Somalia': 656,
#   'Sudan': 8449,
#   'Syria': 1,
#   'Ukraine': 0},
#  2005: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 295,
#   'Mexico': 204,
#   'Pakistan': 128,
#   'Palestine': 138,
#   'Russia': 682,
#   'Somalia': 338,
#   'Sudan': 1311,
#   'Syria': 0,
#   'Ukraine': 0},
#  2006: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 363,
#   'Mexico': 669,
#   'Pakistan': 420,
#   'Palestine': 426,
#   'Russia': 259,
#   'Somalia': 1187,
#   'Sudan': 1974,
#   'Syria': 0,
#   'Ukraine': 0},
#  2007: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 862,
#   'Mexico': 1939,
#   'Pakistan': 1377,
#   'Palestine': 494,
#   'Russia': 176,
#   'Somalia': 1584,
#   'Sudan': 831,
#   'Syria': 0,
#   'Ukraine': 0},
#  2008: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 1734,
#   'Mexico': 3736,
#   'Pakistan': 4589,
#   'Palestine': 650,
#   'Russia': 404,
#   'Somalia': 1731,
#   'Sudan': 1087,
#   'Syria': 0,
#   'Ukraine': 0},
#  2009: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 5298,
#   'Mexico': 5599,
#   'Pakistan': 7489,
#   'Palestine': 717,
#   'Russia': 697,
#   'Somalia': 2146,
#   'Sudan': 691,
#   'Syria': 0,
#   'Ukraine': 0},
#  2010: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 1064,
#   'Mexico': 6202,
#   'Pakistan': 7188,
#   'Palestine': 25,
#   'Russia': 476,
#   'Somalia': 2697,
#   'Sudan': 1303,
#   'Syria': 0,
#   'Ukraine': 0},
#  2011: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 460,
#   'Mexico': 4944,
#   'Pakistan': 3441,
#   'Palestine': 77,
#   'Russia': 396,
#   'Somalia': 2093,
#   'Sudan': 594,
#   'Syria': 4343,
#   'Ukraine': 0},
#  2012: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 1758,
#   'Mexico': 5928,
#   'Pakistan': 3493,
#   'Palestine': 235,
#   'Russia': 516,
#   'Somalia': 2983,
#   'Sudan': 1519,
#   'Syria': 53690,
#   'Ukraine': 0},
#  2013: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 2150,
#   'Mexico': 4448,
#   'Pakistan': 2826,
#   'Palestine': 0,
#   'Russia': 361,
#   'Somalia': 1037,
#   'Sudan': 1903,
#   'Syria': 76462,
#   'Ukraine': 0},
#  2014: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 1538,
#   'Mexico': 3303,
#   'Pakistan': 3569,
#   'Palestine': 2327,
#   'Russia': 174,
#   'Somalia': 1225,
#   'Sudan': 1847,
#   'Syria': 78627,
#   'Ukraine': 4939},
#  2015: {'Burkina Faso': 0,
#   'Democratic Republic of Congo': 637,
#   'Mexico': 4484,
#   'Pakistan': 2366,
#   'Palestine': 0,
#   'Russia': 86,
#   'Somalia': 1239,
#   'Sudan': 2485,
#   'Syria': 59544,
#   'Ukraine': 1890},
#  2016: {'Burkina Faso': 25,
#   'Democratic Republic of Congo': 2143,
#   'Mexico': 4275,
#   'Pakistan': 1086,
#   'Palestine': 0,
#   'Russia': 70,
#   'Somalia': 2055,
#   'Sudan': 1894,
#   'Syria': 53851,
#   'Ukraine': 697},
#  2017: {'Burkina Faso': 34,
#   'Democratic Republic of Congo': 5822,
#   'Mexico': 9716,
#   'Pakistan': 952,
#   'Palestine': 0,
#   'Russia': 53,
#   'Somalia': 2060,
#   'Sudan': 504,
#   'Syria': 38472,
#   'Ukraine': 447},
#  2018: {'Burkina Faso': 171,
#   'Democratic Republic of Congo': 2262,
#   'Mexico': 11175,
#   'Pakistan': 485,
#   'Palestine': 51,
#   'Russia': 36,
#   'Somalia': 2432,
#   'Sudan': 364,
#   'Syria': 21679,
#   'Ukraine': 243},
#  2019: {'Burkina Faso': 1245,
#   'Democratic Republic of Congo': 2395,
#   'Mexico': 10416,
#   'Pakistan': 294,
#   'Palestine': 48,
#   'Russia': 26,
#   'Somalia': 2179,
#   'Sudan': 397,
#   'Syria': 11168,
#   'Ukraine': 311},
#  2020: {'Burkina Faso': 1152,
#   'Democratic Republic of Congo': 3847,
#   'Mexico': 13323,
#   'Pakistan': 392,
#   'Palestine': 0,
#   'Russia': 32,
#   'Somalia': 2091,
#   'Sudan': 559,
#   'Syria': 5650,
#   'Ukraine': 196},
#  2021: {'Burkina Faso': 1454,
#   'Democratic Republic of Congo': 3476,
#   'Mexico': 15020,
#   'Pakistan': 431,
#   'Palestine': 252,
#   'Russia': 0,
#   'Somalia': 2253,
#   'Sudan': 810,
#   'Syria': 1903,
#   'Ukraine': 208},
#  2022: {'Burkina Faso': 2702,
#   'Democratic Republic of Congo': 5498,
#   'Mexico': 12508,
#   'Pakistan': 685,
#   'Palestine': 84,
#   'Russia': 65,
#   'Somalia': 3100,
#   'Sudan': 1184,
#   'Syria': 1651,
#   'Ukraine': 92608},
#  2023: {'Burkina Faso': 6132,
#   'Democratic Republic of Congo': 3854,
#   'Mexico': 10830,
#   'Pakistan': 1161,
#   'Palestine': 26129,
#   'Russia': 197,
#   'Somalia': 4175,
#   'Sudan': 7754,
#   'Syria': 2170,
#   'Ukraine': 75393},
#  2024: {'Burkina Faso': 4253,
#   'Democratic Republic of Congo': 5054,
#   'Mexico': 10940,
#   'Pakistan': 1845,
#   'Palestine': 21399,
#   'Russia': 7814,
#   'Somalia': 2480,
#   'Sudan': 6996,
#   'Syria': 3586,
#   'Ukraine': 68116},
#  2025: {'Burkina Faso': 1847,
#   'Democratic Republic of Congo': 10623,
#   'Mexico': 1417,
#   'Pakistan': 1316,
#   'Palestine': 7138,
#   'Russia': 2974,
#   'Somalia': 2459,
#   'Sudan': 5700,
#   'Syria': 2849,
#   'Ukraine': 25436}}
