# %%
import csv
from collections import defaultdict

# %%
def read_csv_to_dict(file_path, names):
    """
    Reads a CSV file with columns: name, year, number
    and returns a dict of the form:
    {
        year1: {name1: number1, name2: number2, ...},
        year2: {...}
    }
    
    Only includes names in the given list.
    """
    data = defaultdict(dict)

    with open(file_path, newline="", encoding="utf-8") as f:
        reader = csv.DictReader(f)

        for row in reader:
            name = row["Entity"]
            year = int(row["Year"])
            number = int(row["Deaths in ongoing conflicts (best estimate) - Conflict type: all"])

            if name in names:
                data[year][name] = number

    return dict(data)

# %%
names = ['Ukraine', 'Middle East', 'Congo', 'Palestine', 'Sudan', 'Somalia', 'Americas', 'Pakistan', 'Myanmar', 'Iran']

# %%
read_csv_to_dict(file_path='deaths-in-armed-conflicts-by-region.csv', names=names)
# Out:
# {1989: {'World': 67346,
#   'Africa': 41012,
#   'Ethiopia': 18767,
#   'Asia and Oceania': 14570,
#   'Americas': 9414,
#   'Eritrea': 6602,
#   'Afghanistan': 5411,
#   'El Salvador': 4924,
#   'South Sudan': 3907,
#   'Sudan': 3609},
#  1990: {'World': 95411,
#   'Africa': 72786,
#   'Eritrea': 30702,
#   'Ethiopia': 19154,
#   'Asia and Oceania': 14610,
#   'Sri Lanka': 4819,
#   'India': 4785,
#   'South Sudan': 4272,
#   'Middle East': 3995,
#   'Liberia': 3729},
#  1991: {'World': 83952,
#   'Africa': 33941,
#   'Middle East': 25589,
#   'Iraq': 24496,
#   'Asia and Oceania': 17648,
#   'Somalia': 8455,
#   'Sri Lanka': 6646,
#   'Ethiopia': 6388,
#   'Eritrea': 6042,
#   'South Sudan': 4206},
#  1992: {'World': 75567,
#   'Europe': 31456,
#   'Bosnia and Herzegovina': 26868,
#   'Asia and Oceania': 19495,
#   'Africa': 18434,
#   'Somalia': 4729,
#   'Sri Lanka': 4444,
#   'Afghanistan': 4366,
#   'India': 4105,
#   'Tajikistan': 3859},
#  1993: {'World': 73776,
#   'Africa': 40899,
#   'Europe': 17404,
#   'Bosnia and Herzegovina': 13786,
#   'Angola': 12397,
#   'Asia and Oceania': 10482,
#   'Burundi': 10212,
#   'South Sudan': 5877,
#   'Afghanistan': 4097,
#   'Middle East': 3571},
#  1994: {'World': 823499,
#   'Africa': 791653,
#   'Rwanda': 772413,
#   'Asia and Oceania': 13306,
#   'Europe': 9284,
#   'Afghanistan': 9055,
#   'Bosnia and Herzegovina': 7301,
#   'Middle East': 7015,
#   'Turkey': 4159,
#   'Liberia': 4155},
#  1995: {'World': 62301,
#   'Africa': 20653,
#   'Europe': 20202,
#   'Bosnia and Herzegovina': 17252,
#   'Asia and Oceania': 14516,
#   'Afghanistan': 5610,
#   'Middle East': 5518,
#   'Sri Lanka': 4952,
#   'Rwanda': 4230,
#   'Turkey': 3742},
#  1996: {'World': 87379,
#   'Africa': 64389,
#   'Democratic Republic of Congo': 34285,
#   'Burundi': 18183,
#   'Asia and Oceania': 13572,
#   'Middle East': 5115,
#   'Sri Lanka': 4097,
#   'Turkey': 3763,
#   'Afghanistan': 3574,
#   'Liberia': 3069},
#  1997: {'World': 65884,
#   'Africa': 47132,
#   'Democratic Republic of Congo': 13897,
#   'Asia and Oceania': 13182,
#   'Congo': 10426,
#   'Rwanda': 7201,
#   'Afghanistan': 6719,
#   'Middle East': 4463,
#   'Burundi': 4395,
#   'South Sudan': 3574},
#  1998: {'World': 61099,
#   'Africa': 35910,
#   'Asia and Oceania': 19703,
#   'Afghanistan': 12158,
#   'Democratic Republic of Congo': 7693,
#   'Sierra Leone': 5141,
#   'South Sudan': 3887,
#   'Sri Lanka': 3822,
#   'Congo': 3763,
#   'Algeria': 3281},
#  1999: {'World': 100560,
#   'Africa': 75035,
#   'Eritrea': 45191,
#   'Asia and Oceania': 12865,
#   'Europe': 8382,
#   'Democratic Republic of Congo': 7836,
#   'Russia': 6197,
#   'Afghanistan': 5065,
#   'Sierra Leone': 4504,
#   'Nigeria': 3519},
#  2000: {'World': 93766,
#   'Africa': 68059,
#   'Eritrea': 49976,
#   'Asia and Oceania': 16386,
#   'Afghanistan': 5387,
#   'Americas': 4494,
#   'Colombia': 4381,
#   'Europe': 4318,
#   'Russia': 4318,
#   'India': 3967},
#  2001: {'World': 37617,
#   'Africa': 16687,
#   'Asia and Oceania': 11490,
#   'Americas': 7801,
#   'Afghanistan': 5553,
#   'Colombia': 4592,
#   'United States': 2986,
#   'South Sudan': 2809,
#   'Nigeria': 2362,
#   'Angola': 2156},
#  2002: {'World': 41296,
#   'Africa': 22158,
#   'Asia and Oceania': 10611,
#   'Democratic Republic of Congo': 7877,
#   'Americas': 6026,
#   'Colombia': 5947,
#   'Nepal': 4432,
#   'South Sudan': 2958,
#   'India': 2910,
#   'Liberia': 2259},
#  2003: {'World': 40239,
#   'Africa': 18792,
#   'Middle East': 8582,
#   'Iraq': 7993,
#   'Asia and Oceania': 7613,
#   'Sudan': 4761,
#   'Americas': 4704,
#   'Colombia': 4616,
#   'Democratic Republic of Congo': 4310,
#   'Liberia': 3281},
#  2004: {'World': 36080,
#   'Africa': 17257,
#   'Sudan': 8449,
#   'Asia and Oceania': 8228,
#   'Middle East': 5154,
#   'Iraq': 4354,
#   'Americas': 3923,
#   'Colombia': 3307,
#   'Nepal': 2456,
#   'India': 2430},
#  2005: {'World': 20298,
#   'Asia and Oceania': 6880,
#   'Africa': 5222,
#   'Middle East': 4251,
#   'Iraq': 3511,
#   'Americas': 3186,
#   'Colombia': 2815,
#   'India': 1840,
#   'Afghanistan': 1709,
#   'Nepal': 1399},
#  2006: {'World': 27680,
#   'Asia and Oceania': 11669,
#   'Africa': 7603,
#   'Middle East': 6551,
#   'Afghanistan': 4984,
#   'Iraq': 4578,
#   'Sri Lanka': 2147,
#   'India': 2060,
#   'Sudan': 1974,
#   'Chad': 1922},
#  2007: {'World': 28294,
#   'Asia and Oceania': 14248,
#   'Afghanistan': 7021,
#   'Africa': 5694,
#   'Middle East': 5582,
#   'Iraq': 4489,
#   'Americas': 2594,
#   'Sri Lanka': 2536,
#   'Mexico': 1939,
#   'India': 1612},
#  2008: {'World': 39311,
#   'Asia and Oceania': 21497,
#   'Sri Lanka': 8447,
#   'Africa': 8152,
#   'Afghanistan': 5660,
#   'Pakistan': 4589,
#   'Americas': 4533,
#   'Middle East': 4074,
#   'Mexico': 3736,
#   'Iraq': 2752},
#  2009: {'World': 49936,
#   'Asia and Oceania': 27556,
#   'Africa': 12613,
#   'Sri Lanka': 10413,
#   'Pakistan': 7489,
#   'Afghanistan': 6518,
#   'Americas': 6190,
#   'Mexico': 5599,
#   'Democratic Republic of Congo': 5298,
#   'Middle East': 2880},
#  2010: {'World': 33485,
#   'Asia and Oceania': 16800,
#   'Afghanistan': 7190,
#   'Pakistan': 7188,
#   'Africa': 7130,
#   'Americas': 6695,
#   'Mexico': 6202,
#   'Somalia': 2697,
#   'Middle East': 2384,
#   'Iraq': 1856},
#  2011: {'World': 40696,
#   'Africa': 14006,
#   'Asia and Oceania': 13192,
#   'Middle East': 7898,
#   'Afghanistan': 7563,
#   'Americas': 5204,
#   'Mexico': 4944,
#   'Syria': 4343,
#   'Libya': 3917,
#   'Pakistan': 3441},
#  2012: {'World': 89986,
#   'Middle East': 58690,
#   'Syria': 53690,
#   'Asia and Oceania': 13543,
#   'Africa': 10786,
#   'Afghanistan': 7764,
#   'Americas': 6426,
#   'Mexico': 5928,
#   'Pakistan': 3493,
#   'Somalia': 2983},
#  2013: {'World': 114369,
#   'Middle East': 81410,
#   'Syria': 76462,
#   'Africa': 15242,
#   'Asia and Oceania': 12768,
#   'Afghanistan': 8130,
#   'Americas': 4588,
#   'Mexico': 4448,
#   'Iraq': 3997,
#   'Central African Republic': 3396},
#  2014: {'World': 150780,
#   'Middle East': 100240,
#   'Syria': 78627,
#   'Africa': 24330,
#   'Asia and Oceania': 17585,
#   'Iraq': 16437,
#   'Afghanistan': 12565,
#   'Nigeria': 10287,
#   'Europe': 5159,
#   'Ukraine': 4939},
#  2015: {'World': 131101,
#   'Middle East': 81331,
#   'Syria': 59544,
#   'Asia and Oceania': 22310,
#   'Africa': 20482,
#   'Afghanistan': 18016,
#   'Iraq': 11301,
#   'Nigeria': 9093,
#   'Yemen': 8102,
#   'Americas': 4797},
#  2016: {'World': 115646,
#   'Middle East': 72041,
#   'Syria': 53851,
#   'Asia and Oceania': 21692,
#   'Afghanistan': 18991,
#   'Africa': 16359,
#   'Iraq': 12038,
#   'Americas': 4513,
#   'Mexico': 4275,
#   'Yemen': 4021},
#  2017: {'World': 112329,
#   'Middle East': 55203,
#   'Syria': 38472,
#   'Asia and Oceania': 25682,
#   'Afghanistan': 19766,
#   'Africa': 18003,
#   'Americas': 12882,
#   'Iraq': 11417,
#   'Mexico': 9716,
#   'Democratic Republic of Congo': 5822},
#  2018: {'World': 87959,
#   'Middle East': 29380,
#   'Asia and Oceania': 28911,
#   'Afghanistan': 26849,
#   'Syria': 21679,
#   'Africa': 15184,
#   'Americas': 14188,
#   'Mexico': 11175,
#   'Yemen': 4982,
#   'Nigeria': 3125},
#  2019: {'World': 77102,
#   'Asia and Oceania': 32742,
#   'Afghanistan': 30434,
#   'Middle East': 16356,
#   'Africa': 15354,
#   'Americas': 12310,
#   'Syria': 11168,
#   'Mexico': 10416,
#   'Yemen': 2925,
#   'Democratic Republic of Congo': 2395},
#  2020: {'World': 102769,
#   'Africa': 41869,
#   'Ethiopia': 24418,
#   'Asia and Oceania': 22521,
#   'Afghanistan': 20836,
#   'Americas': 16183,
#   'Middle East': 14318,
#   'Mexico': 13323,
#   'Europe': 7878,
#   'Azerbaijan': 7636},
#  2021: {'World': 233639,
#   'Africa': 148715,
#   'Ethiopia': 129481,
#   'Asia and Oceania': 39461,
#   'Afghanistan': 36375,
#   'Middle East': 26940,
#   'Yemen': 23441,
#   'Americas': 18275,
#   'Mexico': 15020,
#   'Democratic Republic of Congo': 3476},
#  2022: {'World': 308614,
#   'Africa': 188312,
#   'Ethiopia': 164991,
#   'Europe': 92983,
#   'Ukraine': 92608,
#   'Americas': 14950,
#   'Mexico': 12508,
#   'Middle East': 6465,
#   'Asia and Oceania': 5904,
#   'Democratic Republic of Congo': 5498},
#  2023: {'World': 160270,
#   'Europe': 76105,
#   'Ukraine': 75393,
#   'Africa': 32851,
#   'Middle East': 31266,
#   'Palestine': 26129,
#   'Americas': 14783,
#   'Mexico': 10830,
#   'Sudan': 7754,
#   'Burkina Faso': 6132},
#  2024: {'World': 159837,
#   'Europe': 75933,
#   'Ukraine': 68116,
#   'Africa': 31920,
#   'Middle East': 31019,
#   'Palestine': 21399,
#   'Americas': 14628,
#   'Mexico': 10940,
#   'Russia': 7814,
#   'Sudan': 6996},
#  2025: {'World': 71683,
#   'Europe': 28410,
#   'Africa': 25602,
#   'Ukraine': 25436,
#   'Middle East': 12526,
#   'Democratic Republic of Congo': 10623,
#   'Palestine': 7138,
#   'Sudan': 5700,
#   'Asia and Oceania': 3105,
#   'Russia': 2974}}
